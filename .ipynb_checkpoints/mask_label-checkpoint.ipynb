# %%
import cv2
import matplotlib.pyplot as plt

import json
img_path="./pics1/10_髁突不对称_下颌升支基本对称.jpg"
label_path=img_path.replace("pics1","pics1_label").replace(".jpg",".json")

# 读取JSON文件
with open(label_path, 'r') as file:
    data = json.load(file)




# 读取现有图像
image = cv2.imread(img_path)

# 检查图像是否成功读取
if image is None:
    print('Error: Image not found or unable to open')
else:
    # 将图像从BGR转换为RGB
    # image_rgb = 
    

    # 定义点的位置和颜色
    point = (1000, 167)
    color = (0, 255, 0)  # 红色 (matplotlib 使用RGB颜色顺序)
    cv2.circle(image, point, 5, color, -1)
    # 绘制点
    plt.imshow(cv2.cvtColor(image, cv2.COLOR_BGR2RGB))
    # plt.scatter([point[0]], [point[1]], c=[color], s=10)
    plt.title('Image with Point')
    plt.axis('off')  # 关闭坐标轴
    plt.show()

# %%
import cv2
import matplotlib.pyplot as plt

import json
img_path="./pics1/267_髁突不对称_下颌升支不对称.jpg"
label_path=img_path.replace("pics1","pics1_label").replace(".jpg",".json")

# 读取JSON文件
with open(label_path, 'r') as file:
    data = json.load(file)


# 读取现有图像
image = cv2.imread(img_path)

# 检查图像是否成功读取
if image is None:
    print('Error: Image not found or unable to open')
else:
    # 将图像从BGR转换为RGB
    # image_rgb = 
    
    for label,point in data.items():
        point = tuple(map(int, point))
        # 定义点的位置和颜色
        # point = (1000, 167)
        color = (0, 255, 0)  # 红色 (matplotlib 使用RGB颜色顺序)
        cv2.circle(image, point, 5, color, -1)
        cv2.putText(image, label, (point[0] + 10, point[1] - 10), cv2.FONT_HERSHEY_SIMPLEX, 0.5, (255, 0, 255), 2)
    # 绘制点
    cv2.imwrite("1.jpg",image)
    plt.imshow(cv2.cvtColor(image, cv2.COLOR_BGR2RGB))
    # plt.scatter([point[0]], [point[1]], c=[color], s=10)
    plt.title('Image with Point')
    plt.axis('off')  # 关闭坐标轴
    plt.show()

# %%
for label,point in data.items():
    print(point)
# Out:
# [1664.6834895014763, 5.35096287727356]
# [2189.0411818027496, 14.649185538291931]
# [2195.306907892227, 358.2869863510132]
# [1909.1526648402214, 511.1905115842819]
# [1648.076328188181, 350.6833493709564]
# [2222.683997154236, -11.57749354839325]
# [2229.1292184591293, 284.10961270332336]
# [2134.7163891792297, 509.4355869293213]
# [1129.5535180568695, 38.55607318878174]
# [682.6286259889603, 29.675558984279633]
# [681.1541915535927, 343.662477016449]
# [883.6916173100471, 459.764851808548]
# [1114.399305343628, 360.90698528289795]
# [653.182511985302, -16.11249279975891]
# [636.5063942074776, 287.24613177776337]
# [721.0311741232872, 480.60932087898254]
# [1401.457835316658, 84.856236577034]
# [1385.9221564531326, 603.0003470182419]
# [1391.5608512163162, 888.139865398407]
# [1126.8150539398193, 1282.91832447052]
# [1471.204511642456, 1299.5382714271545]
# [1807.3616161346436, 1261.6374564170837]
# [651.2787022590637, 459.1498546600342]
# [696.7679371833801, 278.56522965431213]
# ...

# %%
L=['LOCR', 'LOCC','LHC', 'LICC', 'LICC2', 'LLSN']
R=['ROCR', 'ROCC','RHC', 'RICC', 'RICC2', 'RLSN']

# %%
import cv2
import matplotlib.pyplot as plt

import json
img_path="./pics1/7_髁突不对称_下颌升支基本对称.jpg"
label_path=img_path.replace("pics1","pics1_label").replace(".jpg",".json")

# 读取JSON文件
with open(label_path, 'r') as file:
    data = json.load(file)


# 读取现有图像
image = cv2.imread(img_path)

# 检查图像是否成功读取
if image is None:
    print('Error: Image not found or unable to open')
else:
    # 将图像从BGR转换为RGB
    # image_rgb = 
    
    for label in L+R:
        point = tuple(map(int, data[label]))
        # 定义点的位置和颜色
        # point = (1000, 167)
        color = (0, 255, 0)  # 红色 (matplotlib 使用RGB颜色顺序)
        cv2.circle(image, point, 5, color, -1)
        cv2.putText(image, label, (point[0] + 10, point[1] - 10), cv2.FONT_HERSHEY_SIMPLEX, 0.5, (255, 0, 255), 2)
    # 绘制点
    cv2.imwrite("1.jpg",image)
    plt.imshow(cv2.cvtColor(image, cv2.COLOR_BGR2RGB))
    # plt.scatter([point[0]], [point[1]], c=[color], s=10)
    plt.title('Image with Point')
    plt.axis('off')  # 关闭坐标轴
    plt.show()

# %%
data.keys()
# Out:
# dict_keys(['LMMSR', 'LLMSR', 'LLMSB', 'LLMSF', 'LMMSB', 'LMA', 'LMM', 'LMT', 'RMMSR', 'RLMSR', 'RLMSB', 'RLMSF', 'RMMSB', 'RMA', 'RMM', 'RMT', 'NS', 'MD1', 'MD2', 'RCMB', 'MS', 'LCMB', 'RICR', 'RICCP', 'RHCP', 'ROCCP', 'RLSN', 'RICC2', 'RICC', 'RHC', 'ROCC', 'ROCR', 'RMD2', 'RILR', 'RCR', 'RGO', 'RCLMB', 'RMMB', 'RAMC1', 'RMMC1', 'RPMC1', 'RPMC2', 'RMMC2', 'RAMC2', 'LOCR', 'LOCC', 'LHC', 'LICC', 'LICC2', 'LLSN', 'LOCCP', 'LHCP', 'LICCP', 'LICR', 'LMMB', 'LCLMB', 'LGO', 'LCR', 'LILR', 'LMD2', 'LAMC1', 'LMMC1', 'LPMC1', 'LPMC2', 'LMMC2', 'LAMC2'])

# %%
import numpy as np
import matplotlib.pyplot as plt
import bezier
b_xs = []
b_ys = []

L=['LOCR', 'LOCC','LHC', 'LICC', 'LICC2', 'LLSN']
R=['ROCR', 'ROCC','RHC', 'RICC', 'RICC2', 'RLSN']
# xs表示原始数据
# n表示阶数
# k表示索引
def one_bezier_curve(a, b, t):
    return (1 - t) * a + t * b


def n_bezier_curve(xs, n, k, t):
    if n == 1:
        return one_bezier_curve(xs[k], xs[k + 1], t)
    else:
        return (1 - t) * n_bezier_curve(xs, n - 1, k, t) + t * n_bezier_curve(xs, n - 1, k + 1, t)


def bezier_curve(xs, ys, num, b_xs, b_ys):
    n = 5  # 采用5次bezier曲线拟合
    t_step = 1.0 / (num - 1)
    # t_step = 1.0 / num
    print(t_step)
    t = np.arange(0.0, 1 + t_step, t_step)
    print(len(t))
    for each in t:
        b_xs.append(n_bezier_curve(xs, n, 0, each))
        b_ys.append(n_bezier_curve(ys, n, 0, each))


def func():
    xs = [1.0, 2, 3.0, 4.0, 5.0, 1.0]
    ys = [0, 1, 2, 1.0, 2, 0]
    num = 80

    bezier_curve(xs, ys, num, b_xs, b_ys)  # 将计算结果加入到列表中
    print(b_xs, b_ys)
    plt.figure()
    plt.plot(b_xs, b_ys, 'r')  # bezier曲线
    # plt.plot(xs, ys)  # 原曲线
    # plt.show()

func()
# Out:
# 0.012658227848101266
# 80
# ...

# %%
import cv2
import matplotlib.pyplot as plt

import json
img_path="./pics1/267_髁突不对称_下颌升支不对称.jpg"
label_path=img_path.replace("pics1","pics1_label").replace(".jpg",".json")

# 读取JSON文件
with open(label_path, 'r') as file:
    data = json.load(file)


# 读取现有图像
image = cv2.imread(img_path)

L=['LOCR', 'LOCC','LHC', 'LICC', 'LICC2', 'LLSN']
R=['ROCR', 'ROCC','RHC', 'RICC', 'RICC2', 'RLSN']

b_xs_l = []
b_ys_l = []


L_xs = []
L_ys = []

for label in L:
    L_xs.append(int(data[label][0]))
    L_ys.append(int(data[label][1]))

b_xs_r = []
b_ys_r = []

R_xs = []
R_ys = []

for label in R:
    R_xs.append(int(data[label][0]))
    R_ys.append(int(data[label][1]))
# L_xs.append(L_xs[0])
# L_ys.append(L_ys[0])
num = 100
bezier_curve(L_xs, L_ys, num, b_xs_l, b_ys_l)
bezier_curve(R_xs, R_ys, num, b_xs_r, b_ys_r)
plt.imshow(cv2.cvtColor(image, cv2.COLOR_BGR2RGB))
plt.plot(b_xs_l, b_ys_l, 'r-', label='Bezier Curve')  # 红色贝塞尔曲线
plt.plot(b_xs_r, b_ys_r, 'r-', label='Bezier Curve')  # 红色贝塞尔曲线
    
    # point = list(map(int, data[label]))
    # # 定义点的位置和颜色
    # # point = (1000, 167)
    # color = (0, 255, 0)  # 红色 (matplotlib 使用RGB颜色顺序)
    # cv2.circle(image, point, 5, color, -1)
    # cv2.putText(image, label, (point[0] + 10, point[1] - 10), cv2.FONT_HERSHEY_SIMPLEX, 0.5, (255, 0, 255), 2)


# # 绘制点
# cv2.imwrite("1.jpg",image)
# plt.imshow(cv2.cvtColor(image, cv2.COLOR_BGR2RGB))
# # plt.scatter([point[0]], [point[1]], c=[color], s=10)
# plt.title('Image with Point')
# plt.axis('off')  # 关闭坐标轴
# plt.show()
# Out:
# 0.010101010101010102
# 100
# 0.010101010101010102
# 100

# %%
def adjust_coordinates(xs, ys, width, height, alpha=0.1):
    xs_min = max(min(xs) - int((max(xs) - min(xs)) * alpha), 0)
    xs_max = min(max(xs) + int((max(xs) - min(xs)) * alpha), width)
    ys_min = max(min(ys) - int((max(ys) - min(ys)) * alpha), 0)
    ys_max = min(max(ys) + int((max(ys) - min(ys)) * alpha), height)
    return xs_min, xs_max, ys_min, ys_max

H,W,B=image.shape

L_xs_min, L_xs_max, L_ys_min, L_ys_max = adjust_coordinates(L_xs, L_ys, W, H, alpha=0.1)
R_xs_min, R_xs_max, R_ys_min, R_ys_max = adjust_coordinates(R_xs, R_ys, W, H, alpha=0.1)

print(f'L: xs_min={L_xs_min}, xs_max={L_xs_max}, ys_min={L_ys_min}, ys_max={L_ys_max}')
print(f'R: xs_min={R_xs_min}, xs_max={R_xs_max}, ys_min={R_ys_min}, ys_max={R_ys_max}')
# Out:
# L: xs_min=2373, xs_max=2639, ys_min=0, ys_max=408
# R: xs_min=279, xs_max=525, ys_min=0, ys_max=360

# %%
print(f'L: xs_min={L_xs_min}, xs_max={L_xs_max}, ys_min={L_ys_min}, ys_max={L_ys_max}')
print(f'R: xs_min={R_xs_min}, xs_max={R_xs_max}, ys_min={R_ys_min}, ys_max={R_ys_max}')
# Out:
# L: xs_min=2373, xs_max=2639, ys_min=0, ys_max=408
# R: xs_min=279, xs_max=525, ys_min=0, ys_max=360

# %%
H,W,B=image.shape

# %%
L_xs_min=min(L_xs)
L_xs_max=max(L_xs)
L_ys_min=min(L_ys)
L_ys_max=max(L_ys)

aph=0.1
w=L_xs_max-L_xs_min
h=L_ys_max-L_ys_min
h,w=int(h*aph),int(w*aph)

L_xs_min=L_xs_min-w
L_xs_max=L_xs_max+w
L_ys_min=L_ys_min-h
L_ys_max=L_ys_max+h
L_xs_min=L_xs_min if L_xs_min>0 else 0
L_xs_max=W if L_xs_max>W else L_xs_max
L_ys_min=L_ys_min if L_ys_min>0 else 0
L_ys_max=W if L_ys_max>H else L_ys_max

R_xs_min=min(R_xs)
R_xs_max=max(R_xs)
R_ys_min=min(R_ys)
R_ys_max=max(R_ys)


aph=0.1
w=R_xs_max-R_xs_min
h=R_ys_max-R_ys_min
h,w=int(h*aph),int(w*aph)


R_xs_min=R_xs_min-w
R_xs_max=R_xs_max+w
R_ys_min=R_ys_min-h
R_ys_max=R_ys_max+h
R_xs_min=R_xs_min if R_xs_min>0 else 0
R_xs_max=W if R_xs_max>W else R_xs_max
R_ys_min=R_ys_min if R_ys_min>0 else 0
R_ys_max=W if R_ys_max>H else R_ys_max


plt.imshow(cv2.cvtColor(image, cv2.COLOR_BGR2RGB))
plt.plot(x_fine_l, y_fine_l, 'r-', label='Bezier Curve')  # 红色贝塞尔曲线






# R_xs_min=min(R_xs)
# R_xs_max=max(R_xs)
# R_ys_min=min(R_ys)
# R_ys_max=max(R_ys)


# aph=0.1
# w=R_xs_max-R_xs_min
# h=R_ys_max-R_ys_min
# h,w=int(h*aph),int(w*aph)


# R_xs_min=R_xs_min-w
# R_xs_max=R_xs_max+w
# R_ys_min=R_ys_min-h
# R_ys_max=R_ys_max+h


# x_fine_r=[R_xs_min,R_xs_min,R_xs_max,R_xs_max,R_xs_min]
# y_fine_r=[R_ys_min,R_ys_max,R_ys_max,R_ys_min,R_ys_min]

# y_fine_r=[x if x>0 else 0 for x in y_fine_r]
# x_fine_r=[x if x>0 else 0 for x in x_fine_r]
# y_fine_r=[h if x>H else x for x in y_fine_r]
# x_fine_r=[w if x>W else x for x in x_fine_r]
plt.plot(x_fine_r, y_fine_r, 'r-', label='Bezier Curve')  # 红色贝塞尔曲线

# %%
L_xs_min,L_xs_max,L_ys_min,L_ys_max,w,h
# Out:
# (2373, 2639, 0, 408, 20, 30)

# %%
image_label=np.zeros_like(image)
image_label[L_ys_min:L_ys_max,L_xs_min:L_xs_max,:]=image[L_ys_min:L_ys_max,L_xs_min:L_xs_max,:]
image_label[R_ys_min:R_ys_max,R_xs_min:R_xs_max,:]=image[R_ys_min:R_ys_max,R_xs_min:R_xs_max,:]

# %%
[x if x>0 else 0 for x in y_fine_r]
# Out:
# [0, 360, 360, 0, 0]

# %%
L_xs_min,L_xs_max,L_ys_min,L_ys_max
# Out:
# (2394, 2677, 231, 654)

# %%
plt.imshow(cv2.cvtColor(image_label, cv2.COLOR_BGR2RGB))

# %%
from scipy.interpolate import splprep, splev
tck, u = splprep([L_xs,L_ys], s=0)  # s=0 确保曲线经过所有点
u_fine = np.linspace(0, 1, 100)
x_fine, y_fine = splev(u_fine, tck)

def scale_curve(curve, scale_factor):
    center = np.mean(curve, axis=0)
    scaled_curve = (curve - center) * scale_factor + center
    return scaled_curve

# 放大曲线
scale_factor = 1.  # 放大因子
curve_points = np.vstack((x_fine, y_fine)).T
scaled_curve_points = scale_curve(curve_points, scale_factor)
x_scaled, y_scaled = scaled_curve_points[:, 0], scaled_curve_points[:, 1]

plt.imshow(cv2.cvtColor(image, cv2.COLOR_BGR2RGB))
plt.plot(x_scaled, y_scaled, 'r-', label='Bezier Curve')  # 红色贝塞尔曲线

# %%
import cv2
from tqdm import tqdm
import json
# img_path="./pics1/7_髁突不对称_下颌升支基本对称.jpg"
# label_path=img_path.replace("pics1","pics1_label").replace(".jpg",".json")
for label_path in tqdm(glob.glob("./pics1_label/*json")):
    img_path=label_path.replace("pics1_label","pics1").replace(".json",".jpg")
    if "髁突不对称" in label_path:
        new_img_path=img_path.replace("pics1","pics1_imglabel_datasets/no")
    else:
        new_img_path=img_path.replace("pics1","pics1_imglabel_datasets/yes")
    # 读取JSON文件
    with open(label_path, 'r') as file:
        data = json.load(file)
    # 读取现有图像
    image = cv2.imread(img_path)
    H,W,B=image.shape
    L_xs = []
    L_ys = []
    
    for label in L:
        L_xs.append(int(data[label][0]))
        L_ys.append(int(data[label][1]))
    R_xs = []
    R_ys = []
    
    for label in R:
        R_xs.append(int(data[label][0]))
        R_ys.append(int(data[label][1]))
    L_xs_min=min(L_xs)
    L_xs_max=max(L_xs)
    L_ys_min=min(L_ys)
    L_ys_max=max(L_ys)

    aph=0.1
    w=L_xs_max-L_xs_min
    h=L_ys_max-L_ys_min
    h,w=int(h*aph),int(w*aph)
    
    L_xs_min=L_xs_min-w
    L_xs_max=L_xs_max+w
    L_ys_min=L_ys_min-h
    L_ys_max=L_ys_max+h
    L_xs_min=L_xs_min if L_xs_min>0 else 0
    L_xs_max=W if L_xs_max>W else L_xs_max
    L_ys_min=L_ys_min if L_ys_min>0 else 0
    L_ys_max=W if L_ys_max>H else L_ys_max
    
    R_xs_min=min(R_xs)
    R_xs_max=max(R_xs)
    R_ys_min=min(R_ys)
    R_ys_max=max(R_ys)
    
    
    aph=0.1
    w=R_xs_max-R_xs_min
    h=R_ys_max-R_ys_min
    h,w=int(h*aph),int(w*aph)
    
    
    R_xs_min=R_xs_min-w
    R_xs_max=R_xs_max+w
    R_ys_min=R_ys_min-h
    R_ys_max=R_ys_max+h
    R_xs_min=R_xs_min if R_xs_min>0 else 0
    R_xs_max=W if R_xs_max>W else R_xs_max
    R_ys_min=R_ys_min if R_ys_min>0 else 0
    R_ys_max=W if R_ys_max>H else R_ys_max


    image_label=np.zeros_like(image)
    image_label[L_ys_min:L_ys_max,L_xs_min:L_xs_max,:]=image[L_ys_min:L_ys_max,L_xs_min:L_xs_max,:]
    image_label[R_ys_min:R_ys_max,R_xs_min:R_xs_max,:]=image[R_ys_min:R_ys_max,R_xs_min:R_xs_max,:]

    cv2.imwrite(new_img_path,image_label)

# %%
import cv2
from tqdm import tqdm
import json
import os
import glob
import numpy as np

def adjust_coordinates(xs, ys, width, height, alpha=0.1):
    xs_min = max(min(xs) - int((max(xs) - min(xs)) * alpha), 0)
    xs_max = min(max(xs) + int((max(xs) - min(xs)) * alpha), width)
    ys_min = max(min(ys) - int((max(ys) - min(ys)) * alpha), 0)
    ys_max = min(max(ys) + int((max(ys) - min(ys)) * alpha), height)
    return xs_min, xs_max, ys_min, ys_max

def convert_path(image_path):
    # 拆分路径和文件名
    dir_path, filename = os.path.split(image_path)
    
    # 去除文件扩展名
    name, _ = os.path.splitext(filename)
    
    # 分割名称并移除包含 '双侧髁突形态异常' 的部分
    parts = name.split('_')
    parts = [part for index,part in enumerate(parts) if index in [0,2,3]]
    # 组合新的文件名
    new_name = '_'.join(parts) + '.json'
    
    # 返回新的路径
    new_path = os.path.join("./pics1_label/", new_name)
    # print(new_path)
    return new_path

# 定义标签列表
L=['LOCR', 'LOCC','LHC', 'LICC', 'LICC2', 'LLSN']
R=['ROCR', 'ROCC','RHC', 'RICC', 'RICC2', 'RLSN']

for img_path in tqdm(glob.glob("./pics3/*.jpg")):
 
    label_path = convert_path(img_path)
    if "髁突不对称" in label_path:
        new_img_path = img_path.replace("pics3", "pics1_imglabel_datasets/train/no")
    else:
        new_img_path = img_path.replace("pics3", "pics1_imglabel_datasets/train/yes")

    # 读取JSON文件
    with open(label_path, 'r') as file:
        data = json.load(file)

    # 读取现有图像
    image = cv2.imread(img_path)
    H, W, B = image.shape

    # 获取L和R的坐标
    L_xs = [int(data[label][0]) for label in L]
    L_ys = [int(data[label][1]) for label in L]
    R_xs = [int(data[label][0]) for label in R]
    R_ys = [int(data[label][1]) for label in R]

    # 调整L和R的坐标
    L_xs_min, L_xs_max, L_ys_min, L_ys_max = adjust_coordinates(L_xs, L_ys, W, H, alpha=0.3)
    R_xs_min, R_xs_max, R_ys_min, R_ys_max = adjust_coordinates(R_xs, R_ys, W, H, alpha=0.3)

    # 创建标签图像
    # image_label = np.zeros_like(image)
    # image_label[L_ys_min:L_ys_max, L_xs_min:L_xs_max, :] = image[L_ys_min:L_ys_max, L_xs_min:L_xs_max, :]
    # image_label[R_ys_min:R_ys_max, R_xs_min:R_xs_max, :] = image[R_ys_min:R_ys_max, R_xs_min:R_xs_max, :]

    image_label=concatenate_images(image[R_ys_min:R_ys_max, R_xs_min:R_xs_max, :],image[L_ys_min:L_ys_max, L_xs_min:L_xs_max, :], spacing=30)

    # 保存结果图像
    cv2.imwrite(new_img_path, image_label)
    # if "髁突不对称" in label_path:
    #     cv2.imwrite(new_img_path.replace(".jpg","_flip.jpg"), cv2.flip(image_label, 1) )
# Out:
# 100%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 663/663 [00:25<00:00, 26.52it/s]

# %%
x,y,x1,y1=list(map(abs,[L_xs_min-L_xs_max, L_ys_min-L_ys_max,R_xs_min-R_xs_max, R_ys_min-R_ys_max]))

# %%
L_xs_max-L_xs_min
# Out:
# 359

# %%
upper_half = cv2.flip(upper_half, 1)

# %%
for img_path in tqdm(glob.glob("./pics3/*.jpg")):
 
    label_path = convert_path(img_path)
    if "髁突不对称" in label_path:
        new_img_path = img_path.replace("pics3", "pics1_imglabel_datasets/train/no")
    else:
        new_img_path = img_path.replace("pics3", "pics1_imglabel_datasets/train/yes")

# %%
def adjust_coordinates(xs, ys, width, height, alpha=0.1):
    xs_min = max(min(xs) - int((max(xs) - min(xs)) * alpha), 0)
    xs_max = min(max(xs) + int((max(xs) - min(xs)) * alpha), width)
    ys_min = max(min(ys) - int((max(ys) - min(ys)) * alpha), 0)
    ys_max = min(max(ys) + int((max(ys) - min(ys)) * alpha), height)
    return xs_min, xs_max, ys_min, ys_max

# %%
import cv2
import numpy as np

def concatenate_images(img1, img2, spacing=10):
    # 读取图像
    # 获取图像尺寸
    h1, w1, _ = img1.shape
    h2, w2, _ = img2.shape

    # 计算结果图像的尺寸
    result_height = max(h1, h2)
    result_width = w1 + w2 + spacing
    # 创建黑色背景图像
    result = np.zeros((result_height, result_width, 3), dtype=np.uint8)

    # 将两张图像放置在结果图像上
    result[:h1, :w1, :] = img1
    result[:h2, w1 + spacing:w1 + spacing + w2, :] = img2

    return result

# 示例使用

concatenated_image = concatenate_images(image[R_ys_min:R_ys_max, R_xs_min:R_xs_max, :],image[L_ys_min:L_ys_max, L_xs_min:L_xs_max, :], spacing=30)

# 保存或显示结果
# cv2.imwrite('./concatenated_image.jpg', concatenated_image)
cv2.imshow('Concatenated Image', concatenated_image)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
import os

def convert_path(image_path):
    # 拆分路径和文件名
    dir_path, filename = os.path.split(image_path)
    
    # 去除文件扩展名
    name, _ = os.path.splitext(filename)
    
    # 分割名称并移除包含 '双侧髁突形态异常' 的部分
    parts = name.split('_')
    print(parts)
    parts = [part for index,part in enumerate(parts) if index in [0,2,3]]
    
    # 组合新的文件名
    new_name = '_'.join(parts) + '.json'
    
    # 返回新的路径
    new_path = os.path.join("./pics1_label/", new_name)
    return new_path


new_path = convert_path(img_path)
print(new_path)
# Out:
# ['2014', '双侧髁突形态异常', '髁突不对称', '下颌升支基本对称', '杨雨陆']
# ./pics1_label/2014_髁突不对称_下颌升支基本对称.json

# %%
image[L_ys_min:L_ys_max,L_xs_min:L_xs_max,:]
image[R_ys_min:R_ys_max,R_xs_min:R_xs_max,:]

# %%
import cv2
import numpy as np

# 读取图像
img1 = cv2.imread('image1.jpg', cv2.IMREAD_GRAYSCALE)  # 查询图片
img2 = cv2.imread('image2.jpg', cv2.IMREAD_GRAYSCALE)  # 训练图片

# 初始化ORB检测器
orb = cv2.ORB_create()

# 找到关键点和描述符
keypoints1, descriptors1 = orb.detectAndCompute(img1, None)
keypoints2, descriptors2 = orb.detectAndCompute(img2, None)

# 创建BFMatcher对象
bf = cv2.BFMatcher(cv2.NORM_HAMMING, crossCheck=True)

# 匹配描述符
matches = bf.match(descriptors1, descriptors2)

# 按照距离排序
matches = sorted(matches, key=lambda x: x.distance)

# 画出前10个匹配
img_matches = cv2.drawMatches(img1, keypoints1, img2, keypoints2, matches[:10], None, flags=cv2.DrawMatchesFlags_NOT_DRAW_SINGLE_POINTS)

# 显示图片
cv2.imshow('Matches', img_matches)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
import torch
import torch.nn as nn
import torchvision.models as models

# 加载预训练的 VGG16 模型
model = models.resnet101()
model
# Out:
# ResNet(
#   (conv1): Conv2d(3, 64, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3), bias=False)
#   (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (relu): ReLU(inplace=True)
#   (maxpool): MaxPool2d(kernel_size=3, stride=2, padding=1, dilation=1, ceil_mode=False)
#   (layer1): Sequential(
#     (0): Bottleneck(
#       (conv1): Conv2d(64, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (downsample): Sequential(
# ...

# %%
model.fc=nn.Linear(in_features=2048, out_features=2, bias=True)

# %%
model
# Out:
# ResNet(
#   (conv1): Conv2d(3, 64, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3), bias=False)
#   (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (relu): ReLU(inplace=True)
#   (maxpool): MaxPool2d(kernel_size=3, stride=2, padding=1, dilation=1, ceil_mode=False)
#   (layer1): Sequential(
#     (0): Bottleneck(
#       (conv1): Conv2d(64, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (downsample): Sequential(
# ...

# %%
models.resnet101(pretrained=False)
# Out:
# ResNet(
#   (conv1): Conv2d(3, 64, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3), bias=False)
#   (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (relu): ReLU(inplace=True)
#   (maxpool): MaxPool2d(kernel_size=3, stride=2, padding=1, dilation=1, ceil_mode=False)
#   (layer1): Sequential(
#     (0): Bottleneck(
#       (conv1): Conv2d(64, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (downsample): Sequential(
# ...
